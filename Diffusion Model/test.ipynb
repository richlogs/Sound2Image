# %%
import os
import glob
import numpy as np
import torch 
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as T

# %%
dataset_path = "../Data/SubURMP64/images/clean"
train_folder = "train"

image_path = os.path.join(dataset_path, train_folder)
embedding_path = "../Embeddings/audio/subURMPClean/train/all_embeddings_pca.pt"
names_path = "../Embeddings/audio/subURMPClean/train/all_file_names.csv"
img_size = 64
batch_size = 2

# %%
class CustomDataset(Dataset):
    def __init__(self, image_path, name_path, embedding_path, image_size, transform=None):
        self.image_path = image_path
        self.transfrom = transform
        self.name_path = name_path
        self.image_dim = (image_size, image_size)

        self.embedding_array = torch.load(embedding_path)
        self.embedding_names = np.loadtxt(name_path, delimiter=',', dtype=str)

        self.file_list = glob.glob(self.image_path + "*")
        self.data = []
        for class_path in self.file_list:
            for img_pth in glob.glob(class_path + "/*.jpg"):
                self.data.append(img_pth)
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_path = self.data[idx]
        with Image.open(img_path) as image:
            image.Load()
        image = image.convert("RGB")
        img_path = img_path.split("/")[-1]
        embedding_index = np.where(self.embedding_names == img_path)
        embedding = self.embedding_array[embedding_index]
        embedding = embedding.squeeze()

        if self.transform:
            image = self.transform(image)

        return image, embedding

# %%
os.listdir(os.path.join(dataset_path, train_folder, "cello"))
# Out:
# ['cello08_53800.jpg',
#  'cello05_13200.jpg',
#  'cello09_196900.jpg',
#  'cello03_9300.jpg',
#  'cello05_17700.jpg',
#  'cello00_24500.jpg',
#  'cello02_86900.jpg',
#  'cello09_221900.jpg',
#  'cello03_125600.jpg',
#  'cello08_8800.jpg',
#  'cello00_20000.jpg',
#  'cello02_9300.jpg',
#  'cello03_121300.jpg',
#  'cello02_39300.jpg',
#  'cello07_157200.jpg',
#  'cello03_25400.jpg',
#  'cello07_153700.jpg',
#  'cello00_56800.jpg',
#  'cello03_21100.jpg',
#  'cello09_74600.jpg',
#  'cello08_25000.jpg',
#  'cello07_43500.jpg',
#  'cello06_12300.jpg',
#  'cello09_39700.jpg',
#  'cello08_68100.jpg',
#  'cello07_47000.jpg',
#  'cello06_16600.jpg',
#  'cello09_70300.jpg',
#  'cello08_21500.jpg',
#  'cello09_129300.jpg',
#  'cello05_23300.jpg',
#  'cello08_63900.jpg',
#  'cello02_106300.jpg',
#  'cello05_27600.jpg',
#  'cello02_102600.jpg',
#  'cello00_59500.jpg',
#  'cello03_115700.jpg',
#  'cello09_211800.jpg',
#  'cello00_14400.jpg',
#  'cello03_111200.jpg',
#  'cello03_67800.jpg',
#  'cello00_10100.jpg',
#  'cello02_44300.jpg',
#  'cello03_15500.jpg',
#  'cello03_91600.jpg',
#  'cello02_40600.jpg',
#  'cello03_11000.jpg',
#  'cello03_95300.jpg',
#  'cello08_7500.jpg',
#  'cello02_89400.jpg',
#  'cello07_163600.jpg',
#  'cello08_58000.jpg',
#  'cello09_199400.jpg',
#  'cello08_91200.jpg',
#  'cello06_22200.jpg',
#  'cello07_73400.jpg',
#  'cello08_15100.jpg',
#  'cello09_44700.jpg',
#  'cello09_150600.jpg',
#  'cello09_119200.jpg',
#  'cello09_89000.jpg',
#  'cello08_95700.jpg',
#  'cello08_11400.jpg',
#  'cello09_40200.jpg',
#  'cello09_7500.jpg',
#  'cello06_26700.jpg',
#  'cello07_77100.jpg',
#  'cello09_200500.jpg',
#  'cello08_124700.jpg',
#  'cello03_72000.jpg',
#  'cello02_23600.jpg',
#  'cello07_100600.jpg',
#  'cello00_48800.jpg',
#  'cello03_76500.jpg',
#  'cello02_27300.jpg',
#  'cello09_204000.jpg',
#  'cello08_120200.jpg',
#  'cello07_149200.jpg',
#  'cello07_104300.jpg',
#  'cello07_59000.jpg',
#  'cello07_90200.jpg',
#  'cello09_137300.jpg',
#  'cello09_23200.jpg',
#  'cello08_72400.jpg',
#  'cello06_45700.jpg',
#  'cello06_3800.jpg',
#  'cello07_94700.jpg',
#  'cello06_41200.jpg',
#  'cello09_133600.jpg',
#  'cello08_76100.jpg',
#  'cello05_44600.jpg',
#  'cello07_62900.jpg',
#  'cello09_188900.jpg',
#  'cello05_40300.jpg',
#  'cello02_128200.jpg',
#  'cello03_49900.jpg',
#  'cello07_130700.jpg',
#  'cello00_35800.jpg',
#  'cello02_13700.jpg',
#  'cello03_42100.jpg',
#  'cello08_114600.jpg',
#  'cello07_134200.jpg',
#  'cello02_93100.jpg',
#  'cello08_110300.jpg',
#  'cello02_17200.jpg',
#  'cello03_46400.jpg',
#  'cello06_75600.jpg',
#  'cello07_24000.jpg',
#  'cello08_42500.jpg',
#  'cello09_13300.jpg',
#  'cello09_107200.jpg',
#  'cello09_97000.jpg',
#  'cello09_183100.jpg',
#  'cello06_38700.jpg',
#  'cello07_69100.jpg',
#  'cello08_46000.jpg',
#  'cello09_17600.jpg',
#  'cello09_103700.jpg',
#  'cello06_71300.jpg',
#  'cello09_93500.jpg',
#  'cello05_39600.jpg',
#  'cello07_52800.jpg',
#  'cello02_118300.jpg',
#  'cello08_30800.jpg',
#  'cello06_8000.jpg',
#  'cello00_43000.jpg',
#  'cello03_34900.jpg',
#  'cello03_79800.jpg',
#  'cello00_47500.jpg',
#  'cello03_45900.jpg',
#  'cello00_32000.jpg',
#  'cello05_7200.jpg',
#  'cello02_94900.jpg',
#  'cello00_36500.jpg',
#  'cello05_3700.jpg',
#  'cello02_120700.jpg',
#  'cello09_184900.jpg',
#  'cello09_90800.jpg',
#  'cello07_23800.jpg',
#  'cello02_124200.jpg',
#  'cello08_41800.jpg',
#  'cello06_80500.jpg',
#  'cello07_55000.jpg',
#  'cello09_176200.jpg',
#  'cello09_62300.jpg',
#  'cello08_33500.jpg',
#  'cello06_49700.jpg',
#  'cello09_172700.jpg',
#  'cello09_66600.jpg',
#  'cello08_37000.jpg',
#  'cello07_51500.jpg',
#  'cello07_98700.jpg',
#  'cello07_141700.jpg',
#  'cello03_33100.jpg',
#  'cello02_62700.jpg',
#  'cello00_44800.jpg',
#  'cello07_145200.jpg',
#  'cello09_208000.jpg',
#  'cello03_37400.jpg',
#  'cello02_66200.jpg',
#  'cello03_103200.jpg',
#  'cello03_38900.jpg',
#  'cello03_75800.jpg',
#  'cello03_107700.jpg',
#  'cello09_203800.jpg',
#  'cello05_35600.jpg',
#  'cello02_110600.jpg',
#  'cello08_71900.jpg',
#  'cello05_31300.jpg',
#  'cello06_4000.jpg',
#  'cello02_114300.jpg',
#  'cello06_79600.jpg',
#  'cello07_28000.jpg',
#  'cello09_146300.jpg',
#  'cello06_34700.jpg',
#  'cello07_65100.jpg',
#  'cello08_87700.jpg',
#  'cello06_30200.jpg',
#  'cello07_61400.jpg',
#  'cello09_56700.jpg',
#  'cello08_83200.jpg',
#  'cello03_87300.jpg',
#  'cello02_52600.jpg',
#  'cello08_118600.jpg',
#  'cello00_39800.jpg',
#  'cello03_83600.jpg',
#  'cello07_138200.jpg',
#  'cello02_56300.jpg',
#  'cello09_78600.jpg',
#  'cello08_29000.jpg',
#  'cello06_53200.jpg',
#  'cello09_121600.jpg',
#  'cello09_35700.jpg',
#  'cello08_64100.jpg',
#  'cello07_86700.jpg',
#  'cello09_168200.jpg',
#  'cello09_125300.jpg',
#  'cello09_31200.jpg',
#  'cello08_60400.jpg',
#  'cello06_57700.jpg',
#  'cello07_82200.jpg',
#  'cello02_35300.jpg',
#  'cello09_216000.jpg',
#  'cello03_29400.jpg',
#  'cello00_17900.jpg',
#  'cello09_212500.jpg',
#  'cello02_31600.jpg',
#  'cello00_28500.jpg',
#  'cello08_4800.jpg',
#  'cello02_5300.jpg',
#  'cello03_16800.jpg',
#  'cello08_12900.jpg',
#  'cello07_70900.jpg',
#  'cello08_54000.jpg',
#  'cello06_63300.jpg',
#  'cello08_19100.jpg',
#  'cello09_48700.jpg',
#  'cello09_85000.jpg',
#  'cello09_191100.jpg',
#  'cello06_67600.jpg',
#  'cello07_36000.jpg',
#  'cello08_50500.jpg',
#  'cello09_158300.jpg',
#  'cello08_99700.jpg',
#  'cello07_126200.jpg',
#  'cello02_48300.jpg',
#  'cello03_19500.jpg',
#  'cello08_102300.jpg',
#  'cello02_81100.jpg',
#  'cello03_99300.jpg',
#  'cello07_122700.jpg',
#  'cello03_50100.jpg',
#  'cello08_106600.jpg',
#  'cello00_27800.jpg',
#  'cello02_85400.jpg',
#  'cello03_119700.jpg',
#  'cello00_55500.jpg',
#  'cello00_18400.jpg',
#  'cello00_6100.jpg',
#  'cello00_51000.jpg',
#  'cello08_22800.jpg',
#  'cello07_40800.jpg',
#  'cello09_109600.jpg',
#  'cello09_50600.jpg',
#  'cello06_36300.jpg',
#  'cello07_67500.jpg',
#  'cello08_85300.jpg',
#  'cello09_189000.jpg',
#  'cello08_48400.jpg',
#  'cello06_32600.jpg',
#  'cello07_63000.jpg',
#  'cello09_54300.jpg',
#  'cello09_140200.jpg',
#  'cello08_81600.jpg',
#  'cello03_85700.jpg',
#  'cello02_50200.jpg',
#  'cello03_81200.jpg',
#  'cello02_54700.jpg',
#  'cello02_19600.jpg',
#  'cello03_48000.jpg',
#  'cello03_101600.jpg',
#  'cello03_105300.jpg',
#  'cello00_49100.jpg',
#  'cello03_73900.jpg',
#  'cello08_77800.jpg',
#  'cello05_37200.jpg',
#  'cello06_2100.jpg',
#  'cello02_112200.jpg',
#  'cello05_33700.jpg',
#  'cello06_6400.jpg',
#  'cello07_58900.jpg',
#  'cello02_116700.jpg',
#  'cello06_9900.jpg',
#  'cello06_82100.jpg',
#  'cello07_57400.jpg',
#  'cello09_174600.jpg',
#  'cello09_60700.jpg',
#  'cello08_31100.jpg',
#  'cello09_170300.jpg',
#  'cello08_35400.jpg',
#  'cello07_53100.jpg',
#  'cello08_78500.jpg',
#  'cello07_143300.jpg',
#  'cello03_31500.jpg',
#  'cello02_60300.jpg',
#  'cello07_147600.jpg',
#  'cello03_78100.jpg',
#  'cello02_29700.jpg',
#  'cello03_35000.jpg',
#  'cello02_64600.jpg',
#  'cello00_42900.jpg',
#  'cello02_92800.jpg',
#  'cello00_30400.jpg',
#  'cello05_5600.jpg',
#  'cello03_43800.jpg',
#  'cello00_34100.jpg',
#  'cello05_1300.jpg',
#  'cello02_122300.jpg',
#  'cello08_47900.jpg',
#  'cello02_126600.jpg',
#  'cello07_68800.jpg',
#  'cello09_182800.jpg',
#  'cello09_96900.jpg',
#  'cello07_25900.jpg',
#  'cello00_57100.jpg',
#  'cello00_53400.jpg',
#  'cello07_46900.jpg',
#  'cello08_69800.jpg',
#  'cello05_29200.jpg',
#  'cello08_24900.jpg',
#  'cello09_83100.jpg',
#  'cello09_197000.jpg',
#  'cello08_56400.jpg',
#  'cello09_113300.jpg',
#  'cello06_61700.jpg',
#  'cello07_30100.jpg',
#  'cello09_87400.jpg',
#  'cello09_193500.jpg',
#  'cello06_65200.jpg',
#  'cello07_34400.jpg',
#  'cello08_52100.jpg',
#  'cello09_117600.jpg',
#  'cello06_28300.jpg',
#  'cello07_79500.jpg',
#  'cello07_124600.jpg',
#  'cello08_100700.jpg',
#  'cello03_56000.jpg',
#  'cello00_21900.jpg',
#  'cello02_83500.jpg',
#  'cello08_9100.jpg',
#  'cello03_52500.jpg',
#  'cello08_104200.jpg',
#  'cello09_220000.jpg',
#  'cello02_87000.jpg',
#  'cello02_3200.jpg',
#  'cello03_10900.jpg',
#  'cello02_7700.jpg',
#  'cello07_76800.jpg',
#  'cello09_88900.jpg',
#  'cello08_14800.jpg',
#  'cello05_19300.jpg',
#  'cello03_7700.jpg',
#  'cello08_59900.jpg',
#  'cello06_51600.jpg',
#  'cello09_37300.jpg',
#  'cello08_66500.jpg',
#  'cello07_84300.jpg',
#  'cello07_49400.jpg',
#  'cello06_18200.jpg',
#  'cello09_127700.jpg',
#  'cello09_33600.jpg',
#  'cello08_62000.jpg',
#  'cello06_55300.jpg',
#  'cello07_80600.jpg',
#  'cello07_159600.jpg',
#  'cello00_11800.jpg',
#  'cello03_66100.jpg',
#  'cello02_37700.jpg',
#  'cello09_214400.jpg',
#  'cello09_210100.jpg',
#  'cello02_33200.jpg',
#  'cello02_46700.jpg',
#  'cello03_17100.jpg',
#  'cello03_93200.jpg',
#  'cello07_128600.jpg',
#  'cello07_165700.jpg',
#  'cello02_42200.jpg',
#  'cello03_97700.jpg',
#  'cello08_5100.jpg',
#  'cello07_161200.jpg',
#  'cello08_108200.jpg',
#  'cello08_93600.jpg',
#  'cello06_20600.jpg',
#  'cello07_71000.jpg',
#  'cello08_17500.jpg',
#  'cello09_152200.jpg',
#  'cello06_69200.jpg',
#  'cello07_38400.jpg',
#  'cello08_97300.jpg',
#  'cello08_13000.jpg',
#  'cello09_42600.jpg',
#  'cello09_156700.jpg',
#  'cello06_24300.jpg',
#  'cello07_75500.jpg',
#  'cello05_21700.jpg',
#  'cello02_104700.jpg',
#  'cello05_25200.jpg',
#  'cello08_65800.jpg',
#  'cello02_100200.jpg',
#  'cello08_28900.jpg',
#  'cello03_117300.jpg',
#  'cello03_61900.jpg',
#  'cello00_8500.jpg',
#  'cello00_16000.jpg',
#  'cello03_113600.jpg',
#  'cello09_217900.jpg',
#  'cello00_12500.jpg',
#  'cello07_155600.jpg',
#  'cello00_50900.jpg',
#  'cello00_7800.jpg',
#  'cello07_151300.jpg',
#  'cello03_23500.jpg',
#  'cello09_162300.jpg',
#  'cello09_76200.jpg',
#  'cello08_27400.jpg',
#  'cello07_41100.jpg',
#  'cello06_10700.jpg',
#  'cello07_88300.jpg',
#  'cello07_45400.jpg',
#  'cello06_14200.jpg',
#  'cello09_166600.jpg',
#  'cello09_72700.jpg',
#  'cello08_23100.jpg',
#  'cello06_59300.jpg',
#  'cello07_37900.jpg',
#  'cello05_11600.jpg',
#  'cello09_190800.jpg',
#  'cello09_84900.jpg',
#  'cello02_130300.jpg',
#  'cello08_18800.jpg',
#  'cello08_55900.jpg',
#  'cello05_15300.jpg',
#  'cello00_26100.jpg',
#  'cello03_51800.jpg',
#  'cello03_127200.jpg',
#  'cello02_80800.jpg',
#  'cello03_123700.jpg',
#  'cello08_36900.jpg',
#  'cello07_54900.jpg',
#  'cello00_41400.jpg',
#  'cello09_209900.jpg',
#  'cello00_45100.jpg',
#  'cello03_109300.jpg',
#  'cello03_32800.jpg',
#  'cello03_89700.jpg',
#  'cello07_132300.jpg',
#  'cello02_95000.jpg',
#  'cello02_11300.jpg',
#  'cello03_40500.jpg',
#  'cello08_116200.jpg',
#  'cello02_58700.jpg',
#  'cello07_136600.jpg',
#  'cello02_91500.jpg',
#  'cello00_33900.jpg',
#  'cello08_112700.jpg',
#  'cello02_15600.jpg',
#  'cello03_44000.jpg',
#  'cello06_77200.jpg',
#  'cello07_26400.jpg',
#  'cello08_40100.jpg',
#  'cello09_11700.jpg',
#  'cello09_105600.jpg',
#  'cello09_181500.jpg',
#  'cello08_89300.jpg',
#  'cello08_44400.jpg',
#  'cello06_73700.jpg',
#  'cello09_91100.jpg',
#  'cello09_185000.jpg',
#  'cello09_58300.jpg',
#  'cello05_46200.jpg',
#  'cello05_42700.jpg',
#  'cello07_29900.jpg',
#  'cello05_9600.jpg',
#  'cello00_38100.jpg',
#  'cello08_126300.jpg',
#  'cello03_70400.jpg',
#  'cello02_21200.jpg',
#  'cello07_102200.jpg',
#  'cello03_74100.jpg',
#  'cello02_25700.jpg',
#  'cello09_206400.jpg',
#  'cello08_122600.jpg',
#  'cello07_106700.jpg',
#  'cello03_39000.jpg',
#  'cello02_68600.jpg',
#  'cello09_178600.jpg',
#  'cello06_5900.jpg',
#  'cello07_92600.jpg',
#  'cello09_21600.jpg',
#  'cello08_70000.jpg',
#  'cello06_47300.jpg',
#  'cello09_68200.jpg',
#  'cello08_39400.jpg',
#  'cello07_96300.jpg',
#  'cello06_43600.jpg',
#  'cello09_131200.jpg',
#  'cello09_25300.jpg',
#  'cello08_74500.jpg',
#  'cello09_159800.jpg',
#  'cello09_114900.jpg',
#  'cello05_11400.jpg',
#  'cello02_130100.jpg',
#  'cello05_15100.jpg',
#  'cello00_26300.jpg',
#  'cello03_127000.jpg',
#  'cello03_98800.jpg',
#  'cello08_103800.jpg',
#  'cello02_49800.jpg',
#  'cello03_123500.jpg',
#  'cello07_127900.jpg',
#  'cello09_218600.jpg',
#  'cello07_155400.jpg',
#  'cello07_151100.jpg',
#  'cello03_23700.jpg',
#  'cello09_162100.jpg',
#  'cello08_27600.jpg',
#  'cello09_76000.jpg',
#  'cello06_10500.jpg',
#  'cello07_41300.jpg',
#  'cello07_88100.jpg',
#  'cello06_14000.jpg',
#  'cello07_45600.jpg',
#  'cello09_166400.jpg',
#  'cello08_23300.jpg',
#  'cello09_72500.jpg',
#  'cello06_59100.jpg',
#  'cello05_21500.jpg',
#  'cello07_83900.jpg',
#  'cello09_30900.jpg',
#  'cello09_124800.jpg',
#  'cello02_104500.jpg',
#  'cello09_169900.jpg',
#  'cello05_25000.jpg',
#  'cello06_52900.jpg',
#  'cello02_100000.jpg',
#  'cello03_117100.jpg',
#  'cello00_8700.jpg',
#  'cello00_16200.jpg',
#  'cello03_113400.jpg',
#  'cello02_34800.jpg',
#  'cello00_12700.jpg',
#  'cello03_17300.jpg',
#  'cello02_46500.jpg',
#  'cello03_93000.jpg',
#  'cello07_128400.jpg',
#  'cello07_165500.jpg',
#  'cello02_4800.jpg',
#  'cello03_97500.jpg',
#  'cello08_5300.jpg',
#  'cello07_161000.jpg',
#  'cello08_108000.jpg',
#  'cello03_4800.jpg',
#  'cello08_93400.jpg',
#  'cello07_71200.jpg',
#  'cello06_20400.jpg',
#  'cello08_17700.jpg',
#  'cello09_152000.jpg',
#  'cello07_38600.jpg',
#  'cello06_69000.jpg',
#  'cello08_97100.jpg',
#  'cello09_42400.jpg',
#  'cello08_13200.jpg',
#  'cello09_156500.jpg',
#  'cello07_75700.jpg',
#  'cello06_24100.jpg',
#  'cello08_126100.jpg',
#  'cello02_21000.jpg',
#  'cello03_70600.jpg',
#  'cello07_102000.jpg',
#  'cello02_25500.jpg',
#  'cello03_74300.jpg',
#  'cello09_206600.jpg',
#  'cello08_122400.jpg',
#  'cello07_106500.jpg',
#  'cello02_68400.jpg',
#  'cello03_39200.jpg',
#  'cello03_102900.jpg',
#  'cello02_115800.jpg',
#  'cello07_92400.jpg',
#  'cello05_30800.jpg',
#  'cello09_135500.jpg',
#  'cello08_70200.jpg',
#  'cello09_21400.jpg',
#  'cello06_47100.jpg',
#  'cello08_39600.jpg',
#  'cello09_68000.jpg',
#  'cello07_96100.jpg',
#  'cello06_43400.jpg',
#  'cello09_131000.jpg',
#  'cello08_74700.jpg',
#  'cello09_25100.jpg',
#  'cello05_46000.jpg',
#  'cello08_82900.jpg',
#  'cello06_31900.jpg',
#  'cello05_42500.jpg',
#  'cello09_147800.jpg',
#  'cello09_53900.jpg',
#  'cello02_57800.jpg',
#  'cello07_139900.jpg',
#  'cello05_9400.jpg',
#  'cello00_38300.jpg',
#  'cello03_86800.jpg',
#  'cello03_89500.jpg',
#  'cello07_132100.jpg',
#  'cello02_95200.jpg',
#  'cello03_40700.jpg',
#  'cello02_11100.jpg',
#  'cello08_116000.jpg',
#  'cello02_58500.jpg',
#  'cello07_136400.jpg',
#  'cello05_6900.jpg',
#  'cello02_91700.jpg',
#  'cello08_112500.jpg',
#  'cello03_44200.jpg',
#  'cello02_15400.jpg',
#  'cello07_26600.jpg',
#  'cello06_77000.jpg',
#  'cello09_11500.jpg',
#  'cello08_40300.jpg',
#  'cello09_105400.jpg',
#  'cello09_181700.jpg',
#  'cello08_89100.jpg',
#  'cello02_125900.jpg',
#  'cello09_148500.jpg',
#  'cello08_44600.jpg',
#  'cello07_22300.jpg',
#  'cello06_73500.jpg',
#  'cello09_91300.jpg',
#  'cello09_185200.jpg',
#  'cello09_58100.jpg',
#  'cello09_177900.jpg',
#  'cello00_41600.jpg',
#  'cello07_109800.jpg',
#  'cello02_67900.jpg',
#  'cello07_144900.jpg',
#  'cello00_45300.jpg',
#  'cello03_109100.jpg',
#  'cello02_16900.jpg',
#  'cello08_111800.jpg',
#  'cello00_30600.jpg',
#  'cello05_5400.jpg',
#  'cello07_135900.jpg',
#  'cello00_34300.jpg',
#  'cello05_1100.jpg',
#  'cello02_122100.jpg',
#  'cello06_70800.jpg',
#  'cello02_126400.jpg',
#  'cello09_106900.jpg',
#  'cello09_12800.jpg',
#  'cello06_82300.jpg',
#  'cello07_57600.jpg',
#  'cello09_174400.jpg',
#  'cello08_31300.jpg',
#  'cello02_119800.jpg',
#  'cello09_60500.jpg',
#  'cello09_139500.jpg',
#  'cello09_170100.jpg',
#  'cello08_35600.jpg',
#  'cello07_53300.jpg',
#  'cello08_78700.jpg',
#  'cello07_143100.jpg',
#  'cello02_60100.jpg',
#  'cello03_31700.jpg',
#  'cello07_147400.jpg',
#  'cello02_29500.jpg',
#  'cello03_78300.jpg',
#  'cello02_64400.jpg',
#  'cello03_35200.jpg',
#  'cello03_101400.jpg',
#  'cello07_105800.jpg',
#  'cello07_148900.jpg',
#  'cello08_121900.jpg',
#  'cello02_26800.jpg',
#  'cello03_105100.jpg',
#  'cello00_49300.jpg',
#  'cello05_900.jpg',
#  'cello06_40900.jpg',
#  'cello05_37000.jpg',
#  'cello06_2300.jpg',
#  'cello02_112000.jpg',
#  'cello09_22900.jpg',
#  'cello07_91900.jpg',
#  'cello05_33500.jpg',
#  'cello06_6600.jpg',
#  'cello02_116500.jpg',
#  'cello09_109400.jpg',
#  'cello09_50400.jpg',
#  'cello02_129900.jpg',
#  'cello09_144500.jpg',
#  'cello07_67700.jpg',
#  'cello06_36100.jpg',
#  'cello05_41800.jpg',
#  'cello08_85100.jpg',
#  'cello08_48600.jpg',
#  'cello07_63200.jpg',
#  'cello06_32400.jpg',
#  'cello09_54100.jpg',
#  'cello09_140000.jpg',
#  'cello08_81400.jpg',
#  'cello03_85500.jpg',
#  'cello02_50000.jpg',
#  'cello03_81000.jpg',
#  'cello02_54500.jpg',
#  'cello03_48200.jpg',
#  'cello02_19400.jpg',
#  'cello06_51400.jpg',
#  'cello08_66700.jpg',
#  'cello09_37100.jpg',
#  'cello07_84100.jpg',
#  'cello02_107800.jpg',
#  'cello06_18000.jpg',
#  'cello07_49600.jpg',
#  'cello09_127500.jpg',
#  'cello08_62200.jpg',
#  'cello09_33400.jpg',
#  'cello06_55100.jpg',
#  'cello05_22800.jpg',
#  'cello07_80400.jpg',
#  'cello07_159400.jpg',
#  'cello02_37500.jpg',
#  'cello03_66300.jpg',
#  'cello09_214600.jpg',
#  'cello03_110900.jpg',
#  'cello09_210300.jpg',
#  'cello02_33000.jpg',
#  'cello07_110000.jpg',
#  'cello02_3000.jpg',
#  'cello03_94800.jpg',
#  'cello02_7500.jpg',
#  'cello07_166800.jpg',
#  'cello02_45800.jpg',
#  'cello09_155800.jpg',
#  'cello09_41900.jpg',
#  'cello03_3000.jpg',
#  'cello09_118900.jpg',
#  'cello06_23900.jpg',
#  'cello08_90900.jpg',
#  'cello05_19100.jpg',
#  'cello03_7500.jpg',
#  'cello09_83300.jpg',
#  'cello09_197200.jpg',
#  'cello08_56600.jpg',
#  'cello09_113100.jpg',
#  'cello07_30300.jpg',
#  'cello06_61500.jpg',
#  'cello09_87600.jpg',
#  'cello09_193700.jpg',
#  'cello05_12900.jpg',
#  'cello07_34600.jpg',
#  'cello06_65000.jpg',
#  'cello08_52300.jpg',
#  'cello09_117400.jpg',
#  'cello07_79700.jpg',
#  'cello06_28100.jpg',
#  'cello07_124400.jpg',
#  'cello03_120800.jpg',
#  'cello08_100500.jpg',
#  'cello02_8800.jpg',
#  'cello03_56200.jpg',
#  'cello02_83700.jpg',
#  'cello08_9300.jpg',
#  'cello03_52700.jpg',
#  'cello08_104000.jpg',
#  'cello09_220200.jpg',
#  'cello02_87200.jpg',
#  'cello00_57300.jpg',
#  'cello00_53600.jpg',
#  'cello07_156900.jpg',
#  'cello02_38800.jpg',
#  'cello09_128800.jpg',
#  'cello09_71800.jpg',
#  'cello09_165900.jpg',
#  'cello05_29000.jpg',
#  'cello06_13800.jpg',
#  'cello07_28200.jpg',
#  'cello06_79400.jpg',
#  'cello09_146100.jpg',
#  'cello07_65300.jpg',
#  'cello06_34500.jpg',
#  'cello08_87500.jpg',
#  'cello07_61600.jpg',
#  'cello06_30000.jpg',
#  'cello09_56500.jpg',
#  'cello08_83000.jpg',
#  'cello05_47900.jpg',
#  'cello03_87100.jpg',
#  'cello02_52400.jpg',
#  'cello08_118400.jpg',
#  'cello03_83400.jpg',
#  'cello02_56100.jpg',
#  'cello03_103000.jpg',
#  'cello03_107500.jpg',
#  'cello07_103900.jpg',
#  'cello02_20900.jpg',
#  'cello09_24800.jpg',
#  'cello09_130900.jpg',
#  'cello07_97800.jpg',
#  'cello05_35400.jpg',
#  'cello02_110400.jpg',
#  'cello09_69900.jpg',
#  'cello06_46800.jpg',
#  'cello05_31100.jpg',
#  'cello06_4200.jpg',
#  'cello02_114100.jpg',
#  'cello06_80700.jpg',
#  'cello07_55200.jpg',
#  'cello09_176000.jpg',
#  'cello08_33700.jpg',
#  'cello09_62100.jpg',
#  'cello06_49500.jpg',
#  'cello09_172500.jpg',
#  'cello08_37200.jpg',
#  'cello09_66400.jpg',
#  'cello07_51700.jpg',
#  'cello07_98500.jpg',
#  'cello07_141500.jpg',
#  'cello02_62500.jpg',
#  'cello03_33300.jpg',
#  'cello03_108800.jpg',
#  'cello07_145000.jpg',
#  'cello09_208200.jpg',
#  'cello02_66000.jpg',
#  'cello03_37600.jpg',
#  'cello00_32200.jpg',
#  'cello05_7000.jpg',
#  'cello08_117900.jpg',
#  'cello02_10800.jpg',
#  'cello00_36700.jpg',
#  'cello07_133800.jpg',
#  'cello05_3500.jpg',
#  'cello09_59800.jpg',
#  'cello02_120500.jpg',
#  'cello05_48400.jpg',
#  'cello02_124000.jpg',
#  'cello08_88800.jpg',
#  'cello06_76900.jpg',
#  'cello03_119500.jpg',
#  'cello00_55700.jpg',
#  'cello00_18600.jpg',
#  'cello07_150800.jpg',
#  'cello00_6300.jpg',
#  'cello00_51200.jpg',
#  'cello06_58800.jpg',
#  'cello06_15900.jpg',
#  'cello07_89800.jpg',
#  'cello09_77900.jpg',
#  'cello05_14800.jpg',
#  'cello08_54200.jpg',
#  'cello09_48500.jpg',
#  'cello08_19300.jpg',
#  'cello09_85200.jpg',
#  'cello09_191300.jpg',
#  'cello07_36200.jpg',
#  'cello06_67400.jpg',
#  'cello08_50700.jpg',
#  'cello09_115000.jpg',
#  'cello09_158100.jpg',
#  'cello08_99500.jpg',
#  'cello07_126000.jpg',
#  'cello03_19700.jpg',
#  'cello02_48100.jpg',
#  'cello08_102100.jpg',
#  'cello03_54600.jpg',
#  'cello02_81300.jpg',
#  'cello03_99100.jpg',
#  'cello07_122500.jpg',
#  'cello03_126900.jpg',
#  'cello03_50300.jpg',
#  'cello08_106400.jpg',
#  'cello02_85600.jpg',
#  'cello08_109900.jpg',
#  'cello07_160900.jpg',
#  'cello00_28700.jpg',
#  'cello02_43900.jpg',
#  'cello03_129400.jpg',
#  'cello02_5100.jpg',
#  'cello03_92900.jpg',
#  'cello06_25800.jpg',
#  'cello08_96800.jpg',
#  'cello06_68900.jpg',
#  'cello09_47800.jpg',
#  'cello08_29200.jpg',
#  'cello02_101900.jpg',
#  'cello09_78400.jpg',
#  'cello06_53000.jpg',
#  'cello09_121400.jpg',
#  'cello08_64300.jpg',
#  'cello09_35500.jpg',
#  'cello05_24900.jpg',
#  'cello07_86500.jpg',
#  'cello09_125100.jpg',
#  'cello08_60600.jpg',
#  'cello09_31000.jpg',
#  'cello06_57500.jpg',
#  'cello07_82000.jpg',
#  'cello02_35100.jpg',
#  'cello03_64700.jpg',
#  'cello09_216200.jpg',
#  'cello03_29600.jpg',
#  'cello09_212700.jpg',
#  'cello02_31400.jpg',
#  'cello03_116800.jpg',
#  'cello03_15700.jpg',
#  'cello02_44100.jpg',
#  'cello03_91400.jpg',
#  'cello07_167100.jpg',
#  'cello02_40400.jpg',
#  'cello03_95100.jpg',
#  'cello08_7700.jpg',
#  'cello02_89600.jpg',
#  'cello07_163400.jpg',
#  'cello02_2900.jpg',
#  'cello08_58200.jpg',
#  'cello09_199600.jpg',
#  'cello05_18800.jpg',
#  'cello08_91000.jpg',
#  'cello07_73600.jpg',
#  'cello06_22000.jpg',
#  'cello09_44500.jpg',
#  'cello08_15300.jpg',
#  'cello09_150400.jpg',
#  'cello09_119000.jpg',
#  'cello09_89200.jpg',
#  'cello03_2900.jpg',
#  'cello08_95500.jpg',
#  'cello09_40000.jpg',
#  'cello08_11600.jpg',
#  'cello09_7700.jpg',
#  'cello07_77300.jpg',
#  'cello06_26500.jpg',
#  'cello05_23100.jpg',
#  'cello06_54800.jpg',
#  'cello06_19900.jpg',
#  'cello02_106100.jpg',
#  'cello05_27400.jpg',
#  'cello07_85800.jpg',
#  'cello09_36800.jpg',
#  'cello02_102400.jpg',
#  'cello00_59700.jpg',
#  'cello03_115500.jpg',
#  'cello02_32900.jpg',
#  'cello00_14600.jpg',
#  'cello03_111000.jpg',
#  'cello00_10300.jpg',
#  'cello02_39100.jpg',
#  'cello07_157000.jpg',
#  'cello03_25600.jpg',
#  'cello07_153500.jpg',
#  'cello03_21300.jpg',
#  'cello09_160500.jpg',
#  'cello08_25200.jpg',
#  'cello09_74400.jpg',
#  'cello06_12100.jpg',
#  'cello07_43700.jpg',
#  'cello05_28900.jpg',
#  'cello08_68300.jpg',
#  'cello09_39500.jpg',
#  'cello06_16400.jpg',
#  'cello07_47200.jpg',
#  'cello08_21700.jpg',
#  'cello09_70100.jpg',
#  'cello09_129100.jpg',
#  'cello06_29800.jpg',
#  'cello06_64900.jpg',
#  'cello05_13000.jpg',
#  'cello09_112800.jpg',
#  'cello03_9100.jpg',
#  'cello05_17500.jpg',
#  'cello00_24700.jpg',
#  'cello08_105900.jpg',
#  'cello03_125400.jpg',
#  'cello07_121800.jpg',
#  'cello00_20200.jpg',
#  'cello02_9100.jpg',
#  'cello03_121100.jpg',
#  'cello05_39400.jpg',
#  'cello09_171800.jpg',
#  'cello02_118100.jpg',
#  'cello06_8200.jpg',
#  'cello00_43200.jpg',
#  'cello00_47700.jpg',
#  'cello02_61800.jpg',
#  'cello07_142800.jpg',
#  'cello07_130500.jpg',
#  'cello03_42300.jpg',
#  'cello02_13500.jpg',
#  'cello08_114400.jpg',
#  'cello07_134000.jpg',
#  'cello02_93300.jpg',
#  'cello08_110100.jpg',
#  'cello03_46600.jpg',
#  'cello02_17000.jpg',
#  'cello07_24200.jpg',
#  'cello06_75400.jpg',
#  'cello09_13100.jpg',
#  'cello08_42700.jpg',
#  'cello09_107000.jpg',
#  'cello07_69300.jpg',
#  'cello06_38500.jpg',
#  'cello09_17400.jpg',
#  'cello08_46200.jpg',
#  'cello09_103500.jpg',
#  'cello06_71100.jpg',
#  'cello09_93700.jpg',
#  'cello02_123800.jpg',
#  'cello05_44400.jpg',
#  'cello09_141900.jpg',
#  'cello09_55800.jpg',
#  'cello08_84800.jpg',
#  'cello05_40100.jpg',
#  ...]

# %%
train_dataset = CustomDataset(image_path=image_path, name_path=names_path, embedding_path=embedding_path, image_size=img_size)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                                  # num_workers=args.num_workers
                                  )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/richardkyle/Documents/University/current/AIML589/Diffusion-Models-pytorch-main/test.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/richardkyle/Documents/University/current/AIML589/Diffusion-Models-pytorch-main/test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
#       <a href='vscode-notebook-cell:/Users/richardkyle/Documents/University/current/AIML589/Diffusion-Models-pytorch-main/test.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>                                   # num_workers=args.num_workers
#       <a href='vscode-notebook-cell:/Users/richardkyle/Documents/University/current/AIML589/Diffusion-Models-pytorch-main/test.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>                                   )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:344, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     342 else:  # map-style
#     343     if shuffle:
# --> 344         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     345     else:
#     346         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/sampler.py:107, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     103     raise TypeError("replacement should be a boolean value, but got "
#     104                     "replacement={}".format(self.replacement))
#     106 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 107     raise ValueError("num_samples should be a positive integer "
#     108                      "value, but got num_samples={}".format(self.num_samples))
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
def get_data(args):
    train_transforms = torchvision.transforms.Compose([
        T.Resize(args.img_size + int(.25*args.img_size)),  # args.img_size + 1/4 *args.img_size
        T.RandomResizedCrop(args.img_size, scale=(0.8, 1.0)),
        T.ToTensor(),
        T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])

    val_transforms = torchvision.transforms.Compose([
        T.Resize(args.img_size),
        T.ToTensor(),
        T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])

    train_dataset = CustomDataset(args, os.path.join(args.dataset_path, args.train_folder), transform=train_transforms)
    val_dataset = CustomDataset(args, os.path.join(args.dataset_path, args.val_folder), transform=val_transforms)
    
    # if args.slice_size>1:
    #     train_dataset = torch.utils.data.Subset(train_dataset, indices=range(0, len(train_dataset), args.slice_size))
    #     val_dataset = torch.utils.data.Subset(val_dataset, indices=range(0, len(val_dataset), args.slice_size))

    train_dataloader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True,
                                  # num_workers=args.num_workers
                                  )
    val_dataset = DataLoader(val_dataset, batch_size=2*args.batch_size, shuffle=False, 
                             #num_workers=args.num_workers
                             )
    return train_dataloader, val_dataset
